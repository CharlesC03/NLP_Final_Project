# %% [markdown]
# # Measuring the Bias of the Teacher Model

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from tqdm.notebook import tqdm
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay, f1_score, accuracy_score, precision_score, recall_score
# import torch

from typing import Callable, Dict
import numpy as np

from collections import defaultdict
from typing import List
import re

import sys
sys.path.insert(0, '..')
# from notifier import Notifier

import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")
# palette = sns.choose_colorbrewer_palette("qualitative")

# %%
# notifier = Notifier()
# notifier.set_usage(False) # Comment out for no notifications

# %%
race_palette = ["b", "r", 'g']
gender_palette = ["c", "m"]

# %% [markdown]
# ## Functions

# %%
def import_predictions(file_path: str, rm_columns: List[str] = [], rename_columns:  Dict[str, str] = {}, parquet_engine: str = "auto", apply_column_funcs: Dict[str, callable] = {}) -> pd.DataFrame:
    """Imports predictions from a file and optionally removes/renames columns. Function documentation generated with Claude Sonnet 4.5
        
        Args:
            file_path (str): Path to the file containing predictions (.csv or .parquet)
            rm_columns (list, optional): List of column names to remove. Defaults to [].
            rename_columns (dict, optional): Dictionary mapping old column names to new names. Defaults to {}.
        
        Returns:
            pd.DataFrame: The processed dataframe with predictions.
        
        Raises:
            ValueError: If file format is unsupported or specified columns don't exist.
        """
    temp_ds = None
    if file_path.endswith('.csv'):
        temp_ds = pd.read_csv(file_path)
    elif file_path.endswith('.parquet'):
        temp_ds = pd.read_parquet(file_path, engine=parquet_engine)
    if temp_ds is None:
        raise ValueError("Unsupported file format. Only .csv and .parquet are supported.")
    
    if len(rm_columns) > 0:
        # Sanity checks for removing columns
        if not all(col in temp_ds.columns for col in rm_columns):
            raise ValueError("One or more columns to remove do not exist in the dataset.")
        # Remove the specified columns
        temp_ds = temp_ds.drop(columns=rm_columns)
    if len(rename_columns) > 0:
        # Sanity checks for renaming columns
        if not all(col in temp_ds.columns for col in rename_columns.keys()):
            raise ValueError("One or more columns to rename do not exist in the dataset.")
        if any(col in temp_ds.columns for col in rename_columns.values()):
            raise ValueError("One or more new column names already exist in the dataset.")
        # Rename the columns
        temp_ds = temp_ds.rename(columns=rename_columns)
    if len(apply_column_funcs) > 0:
        # Sanity checks for applying functions to columns
        if not all(col in temp_ds.columns or col in rename_columns for col in apply_column_funcs.keys()):
            raise ValueError("One or more columns specified for function application do not exist in the dataset.")
        for col, func in apply_column_funcs.items():
            # Check if the function is callable
            if not callable(func):
                raise ValueError(f"The function provided for column '{col}' is not callable.")
            # Set column name after renaming if given initial name
            col_name = col if col not in rename_columns else rename_columns[col]
            if col_name not in temp_ds.columns:
                raise ValueError(f"Column '{col}' specified for function application does not exist in the dataset.")
            # Apply the function to the specified column
            temp_ds[col_name] = temp_ds[col_name].apply(func)
    return temp_ds

def import_to_ds(ds: pd.DataFrame, file_path: str, prediction_columns: List[str], column_key: str = 'sentence', rename_columns:  Dict[str, str] = {}, parquet_engine: str = "auto") -> pd.DataFrame:
    """Imports predictions from a file and merges them with the existing dataset. Function documentation generated with Claude Sonnet 4.5
        
        Args:
            ds (pd.DataFrame): The existing dataset to merge predictions into.
            file_path (str): Path to the file containing predictions (.csv or .parquet).
            prediction_column (str): Name of the column containing predictions.
            rename_columns (dict, optional): Dictionary mapping old column names to new names. Defaults to {}.
        
        Returns:
            pd.DataFrame: The dataset with predictions merged in.
        """
    # import the dataframe
    temp_ds = import_predictions(file_path, rename_columns=rename_columns, parquet_engine=parquet_engine)
    merge_key = column_key if column_key in temp_ds.columns else rename_columns.get(column_key, None)
    if merge_key is None:
        raise ValueError(f"Column key '{column_key}' does not exist in the imported dataset.")
    if merge_key not in ds.columns:
        raise ValueError(f"Column key '{column_key}' does not exist in the main dataset.")
    # Set the predicted column name to a renamed column if it is in the renamed columns
    pred_col_names = [col if col not in rename_columns else rename_columns[col] for col in prediction_columns]
    match_columns = set(pred_col_names) - set(temp_ds.columns)
    # Sanity check to ensure all prediction columns exist
    if len(match_columns) > 0:
        raise ValueError(f"{match_columns} columns do not exist in the imported dataset.")
    # Check if any columns already exist in the main dataset
    existing_columns = set(pred_col_names) & set(ds.columns)
    if len(existing_columns) > 0:
        raise ValueError(f"{existing_columns} columns already exist in the main dataset.")
    # Merge the predictions into the main dataset
    temp_ds = temp_ds[[column_key, *pred_col_names]]
    ds = ds.merge(temp_ds, on=column_key, how='left')
    return ds

# %%
def compare_differences(df, constants: List[str], variable: str, metric_column: str, curr_info = {}, concat_df=None) -> pd.DataFrame:
    """Compares the differences in means for a variable across different constant categories.

    Args:
        df (pd.DataFrame): The dataframe containing the data.
        constants (List[str]): List of column names to keep constant during comparisons.
        variable (str): The variable column name to compare mean values for.
        curr_info (dict, optional): Current information about the constant categories. Defaults to {}.
        concat_df (pd.DataFrame, optional): Dataframe to concatenate results to. Defaults to None.

    Returns:
        pd.DataFrame: A dataframe containing the means for each category of the variable across the constant categories.
    """
    res_df = pd.DataFrame() if concat_df is None else concat_df
    if len(constants) == 0:
        # Base case: calculate means for each category of the variable
        return pd.concat([concat_df,
                          pd.DataFrame([{
                              **curr_info,
                              **{f'{v}_data': df[df[variable] == v][metric_column].to_numpy()#.mean()
                                 for v in df[variable].unique()
                                 if len(df[df[variable] == v]) > 0}
                                 }],)], ignore_index=True)
    # Iterate through each of the values for the columns we want to keep constant among comparisons
    for value in df[constants[0]].unique():
        temp_df = df[df[constants[0]] == value]
        if len(temp_df) == 0:
            continue
        new_constants = constants[1:]
        new_info = curr_info.copy()
        new_info[constants[0]] = value
        res_df = compare_differences(temp_df, new_constants, variable, metric_column, new_info, res_df)
    return res_df

# %% [markdown]
# ## Analyzing the Accuracy of the Models

# %% [markdown]
# Creates text to add to latex table for the report

# %%
df = import_predictions("../data/llama3.1/test.csv", rm_columns=['label_0'],rename_columns={'label_1': 'Llama 3.1 8B Instruct'}, apply_column_funcs={'label_1': lambda x: int(x > 0.5)})
df = import_to_ds(df, "datasets/imdb_bow_test_predictions.csv", prediction_columns=['pred_label'], column_key="text", rename_columns={'pred_label': 'BOW Baseline'})
df = import_to_ds(df, "datasets/imdb_bow_distilled_test_predictions.csv", prediction_columns=['pred_label'], column_key="text", rename_columns={'pred_label': 'BOW Distilled'})
df = import_to_ds(df, "datasets/imdb_cnn_test_predictions.csv", prediction_columns=['pred_label'], column_key="text", rename_columns={'pred_label': 'CNN Baseline'})
df = import_to_ds(df, "datasets/imdb_cnn_distilled_test_predictions.csv", prediction_columns=['pred_label'], column_key="text", rename_columns={'pred_label': 'CNN Distilled'})
df = import_to_ds(df, "datasets/distilbert_trained_IMDB_predictions.parquet", prediction_columns=['pred_label'], column_key="text", rename_columns={'pred_label': 'DistilBERT Baseline'})
df = import_to_ds(df, "datasets/distilbert_distilled_IMDB_predictions.parquet", prediction_columns=['pred_label'], column_key="text", rename_columns={'pred_label': 'DistilBERT Distilled'})

# %%
df.nunique(dropna=False)
# Out:
# text                     24791
# label                        2
# Llama 3.1 8B Instruct        2
# BOW Baseline                 2
# BOW Distilled                2
# CNN Baseline                 2
# CNN Distilled                2
# DistilBERT Baseline          2
# DistilBERT Distilled         2
# dtype: int64

# %%
df['DistilBERT Baseline'].value_counts(dropna=False)
# Out:
# DistilBERT Baseline
# 1    12488
# 0    12303
# Name: count, dtype: int64

# %%
print("Model & Accuracy & Precision & Recall & F1 Score\\\\")
print("\\hline")
for col in df.columns[2:]:
    # Checks if the column contains any NaN values, if it does then it will skip the column since it indicates it was not tested on the testing dataset
    if df[col].isna().any():
        continue
    accuracy = accuracy_score(df['label'], df[col])
    precision = precision_score(df['label'], df[col])
    recall = recall_score(df['label'], df[col])
    f1 = f1_score(df['label'], df[col])
    print(f"{col} & {accuracy:.4f} & {precision:.4f} & {recall:.4f} & {f1:.4f} \\\\")
    print("\\hline")
# Out:
# Model & Accuracy & Precision & Recall & F1 Score\\
# \hline
# Llama 3.1 8B Instruct & 0.9458 & 0.9242 & 0.9717 & 0.9474 \\
# \hline
# BOW Baseline & 0.8765 & 0.8577 & 0.9042 & 0.8803 \\
# \hline
# BOW Distilled & 0.8693 & 0.8395 & 0.9147 & 0.8755 \\
# \hline
# CNN Baseline & 0.8703 & 0.8738 & 0.8669 & 0.8703 \\
# \hline
# CNN Distilled & 0.8702 & 0.8651 & 0.8786 & 0.8718 \\
# \hline
# DistilBERT Baseline & 0.9662 & 0.9649 & 0.9678 & 0.9664 \\
# \hline
# DistilBERT Distilled & 0.9180 & 0.8898 & 0.9551 & 0.9213 \\
# \hline

# %% [markdown]
# Creates confusion matrices for each of teacher and student baseline and distilled models from the IMDB test datasets

# %%
teacher_test_df = pd.read_csv("../data/llama3.1/test.csv")
teacher_train_df = pd.read_csv("../data/llama3.1/train.csv")
teacher_test_df['prediction'] = teacher_test_df[['label_0', 'label_1']].to_numpy().argmax(axis=1)
teacher_train_df['prediction'] = teacher_train_df[['label_0', 'label_1']].to_numpy().argmax(axis=1)
print(f"Train:{teacher_train_df.head()}\n")
print(f"Test:{teacher_test_df.head()}\n")
# Out:
# Train:                                                text  label   label_0  \
# 0  The volleyball genre is strangely overlooked b...      0  0.046020
# 1  I got interested in this movie because somebod...      0  0.782700
# 2  Sure, I like some indie films. A lot, actually...      0  0.955600
# 3  Blademaster is definitely a memorable entry in...      1  0.069030
# 4  This World War II Popeye cartoon had some very...      1  0.002823
#
#    label_1  prediction
# 0  0.95400           1
# 1  0.21730           0
# 2  0.04453           0
# 3  0.93100           1
# 4  0.99700           1
#
# Test:                                                text  label   label_0  \
# 0  This sci-fi great fortunately has little to do...      1  0.001636
# 1  Yet another recent comedy that shows that Holl...      0  0.970000
# 2  I was looking on Imdbs bottom 100 because i th...      0  0.970000
# 3  Bo Derek will not go down in history as a grea...      0  0.925000
# 4  During the Civil War, there were many cases of...      0  0.006290
#
#    label_1  prediction
# 0  0.99850           1
# 1  0.02975           0
# 2  0.02998           0
# 3  0.07530           0
# 4  0.99370           1

# %%
fig, ax = plt.subplots(figsize=(8, 8))

train_f1_score = f1_score(
    teacher_train_df['label'], teacher_train_df['prediction']
)

ConfusionMatrixDisplay.from_predictions(
    teacher_train_df['label'], teacher_train_df['prediction'],
    display_labels=["Negative", "Positive"],
    cmap=plt.cm.Blues,
    normalize='true',
    ax = ax
)

ax.set_title("Llama Teacher Model Confusion Matrix - Train Set", fontsize=16)

fig.tight_layout()

fig.savefig("graphs/llama/model_confusion_matrix_train.png", dpi=300)

print(f"Llama Teacher Model F1 Score (Train Set): {train_f1_score:.4f}")

plt.show()
# Out:
# Llama Teacher Model F1 Score (Train Set): 0.9416

# %%
fig, ax = plt.subplots(figsize=(8, 8))

test_f1_score = f1_score(
    teacher_test_df['label'], teacher_test_df['prediction']
)


ConfusionMatrixDisplay.from_predictions(
    teacher_test_df['label'], teacher_test_df['prediction'],
    display_labels=["Negative", "Positive"],
    cmap=plt.cm.Blues,
    normalize='true',
    ax = ax
)

ax.set_title("Llama Teacher Model Confusion Matrix - Test Set", fontsize=16)
fig.tight_layout()

fig.savefig("graphs/llama/model_confusion_matrix_test.png", dpi=300)

print(f"Llama Teacher Model F1 Score (Test Set): {test_f1_score:.4f}")

plt.show()
# Out:
# Llama Teacher Model F1 Score (Test Set): 0.9474

# %%
bow_test_df = pd.read_csv("datasets/imdb_bow_test_predictions.csv")

fig, ax = plt.subplots(figsize=(8, 8))

test_f1_score = f1_score(
    bow_test_df['true_label'], bow_test_df['pred_label']
)

ConfusionMatrixDisplay.from_predictions(
    bow_test_df['true_label'], bow_test_df['pred_label'],
    display_labels=["Negative", "Positive"],
    cmap=plt.cm.Blues,
    normalize='true',
    ax = ax
)

ax.set_title("BOW Baseline Model Confusion Matrix - Test Set", fontsize=16)

fig.tight_layout()

fig.savefig("graphs/bow/model_baseline_confusion_matrix_test.png", dpi=300)

print(f"BOW Baseline Model F1 Score (Test Set): {test_f1_score:.4f}")

plt.show()
# Out:
# BOW Baseline Model F1 Score (Test Set): 0.8803

# %%
bow_test_df = pd.read_csv("datasets/imdb_bow_distilled_test_predictions.csv")

fig, ax = plt.subplots(figsize=(8, 8))

test_f1_score = f1_score(
    bow_test_df['true_label'], bow_test_df['pred_label']
)

ConfusionMatrixDisplay.from_predictions(
    bow_test_df['true_label'], bow_test_df['pred_label'],
    display_labels=["Negative", "Positive"],
    cmap=plt.cm.Blues,
    normalize='true',
    ax = ax
)

ax.set_title("BOW Distilled Model Confusion Matrix - Test Set", fontsize=16)

fig.tight_layout()

fig.savefig("graphs/bow/model_distilled_confusion_matrix_test.png", dpi=300)

print(f"BOW Distilled Model F1 Score (Test Set): {test_f1_score:.4f}")

plt.show()
# Out:
# BOW Distilled Model F1 Score (Test Set): 0.8755

# %%
cnn_test_df = pd.read_csv("datasets/imdb_cnn_test_predictions.csv")

fig, ax = plt.subplots(figsize=(8, 8))

test_f1_score = f1_score(
    cnn_test_df['true_label'], cnn_test_df['pred_label']
)

ConfusionMatrixDisplay.from_predictions(
    cnn_test_df['true_label'], cnn_test_df['pred_label'],
    display_labels=["Negative", "Positive"],
    cmap=plt.cm.Blues,
    normalize='true',
    ax = ax
)

ax.set_title("CNN Baseline Model Confusion Matrix - Test Set", fontsize=16)

fig.tight_layout()

fig.savefig("graphs/cnn/model_baseline_confusion_matrix_test.png", dpi=300)

print(f"CNN Baseline Model F1 Score (Test Set): {test_f1_score:.4f}")

plt.show()
# Out:
# CNN Baseline Model F1 Score (Test Set): 0.8703

# %%
cnn_test_df = pd.read_csv("datasets/imdb_cnn_distilled_test_predictions.csv")

fig, ax = plt.subplots(figsize=(8, 8))

test_f1_score = f1_score(
    cnn_test_df['true_label'], cnn_test_df['pred_label']
)

ConfusionMatrixDisplay.from_predictions(
    cnn_test_df['true_label'], cnn_test_df['pred_label'],
    display_labels=["Negative", "Positive"],
    cmap=plt.cm.Blues,
    normalize='true',
    ax = ax
)

ax.set_title("CNN Distilled Model Confusion Matrix - Test Set", fontsize=16)

fig.tight_layout()

fig.savefig("graphs/cnn/model_distilled_confusion_matrix_test.png", dpi=300)

print(f"CNN Distilled Model F1 Score (Test Set): {test_f1_score:.4f}")

plt.show()
# Out:
# CNN Distilled Model F1 Score (Test Set): 0.8718

# %%
distilbert_test_df = pd.read_parquet("datasets/distilbert_distilled_IMDB_predictions.parquet")

fig, ax = plt.subplots(figsize=(8, 8))

test_f1_score = f1_score(
    distilbert_test_df['label'], distilbert_test_df['pred_label']
)

ConfusionMatrixDisplay.from_predictions(
    distilbert_test_df['label'], distilbert_test_df['pred_label'],
    display_labels=["Negative", "Positive"],
    cmap=plt.cm.Blues,
    normalize='true',
    ax = ax
)

ax.set_title("DistilBERT Distilled Model Confusion Matrix - Test Set", fontsize=16)

fig.tight_layout()

fig.savefig("graphs/distilbert/model_distilled_confusion_matrix_test.png", dpi=300)

print(f"DistilBERT Distilled Model F1 Score (Test Set): {test_f1_score:.4f}")

plt.show()
# Out:
# DistilBERT Distilled Model F1 Score (Test Set): 0.9213

# %%
distilbert_test_df = pd.read_parquet("datasets/distilbert_trained_IMDB_predictions.parquet")

fig, ax = plt.subplots(figsize=(8, 8))

test_f1_score = f1_score(
    distilbert_test_df['label'], distilbert_test_df['pred_label']
)

ConfusionMatrixDisplay.from_predictions(
    distilbert_test_df['label'], distilbert_test_df['pred_label'],
    display_labels=["Negative", "Positive"],
    cmap=plt.cm.Blues,
    normalize='true',
    ax = ax
)

ax.set_title("DistilBERT Baseline Model Confusion Matrix - Test Set", fontsize=16)

fig.tight_layout()

fig.savefig("graphs/distilbert/model_baseline_confusion_matrix_test.png", dpi=300)

print(f"DistilBERT Baseline Model F1 Score (Test Set): {test_f1_score:.4f}")

plt.show()
# Out:
# DistilBERT Baseline Model F1 Score (Test Set): 0.9664

# %% [markdown]
# ## Running Teacher Model on the EEC Dataset
# <style>
# pre {
#     font-size: 0.8em;
# }
# </style>
# ### Teacher Parquet Files
# ---
# ##### `datasets/teacher_model_predictions.parquet`
# This used a set few shot prompt (the code of which is viable below). This was how the test dataset was created.
# ```python
# def model_prompt(text: str, _) -> str:
#     prompt_output = f"""Classify the sentiment of the following texts as either Negative, or Positive.
#
# Text: ...but a lousy film. As Maltin says this was Christopher Lee's attempt to make a serious horror film. Well, it is serious...TOO serious! The plot is silly and slow (something about old people inhabiting the bodies of young children to achieve immortality)...the film is all talk talk talk talk talk talk talk about the same things over and over again. I actually dozed off a few times! The film is sooooo dull! The cast sleepwalks through this with the sole exceptions of Peter Cushing and Lee...but this was probably a labor of love for both (they often complained about horror movies being too violent...well, this has NO violence!). Avoid at all costs...unless you have insomnia...this will put you to sleep!
# Sentiment: Negative
#
# Text: Considering it was made on a low budget, THE DAY TIME ENDED manages to make the most of its budget with some surprisingly good special effects work.<br /><br />The story involves a family who are about to move into their solar-powered home in an isolated part of the Mojave Desert in southwestern California, only to find it trashed--by motorcycle vandals, they think. But their youngest daughter (Natasha Ryan) has begun to see mysterious things--a green pyramid, strange humanoid figures, etc. And only recently, the light from a trinary star explosion has caused extremely unusual auroras to show up in the desert skies. Thus the family, led by Jim Davis and Dorothy Malone, finds themselves face-to-face with strange alien forces who have put them in a time-and-space warp.<br /><br />Mixing in elements of 2001: A SPACE ODYSSEY and CLOSE ENCOUNTERS OF THE THIRD KIND, THE DAY TIME ENDED, despite its obvious flaws and uneven acting, remains interesting due to the superb special effects work of David Allen. The desert setting is very appropriate for this film's close encounters; and while the movie cannot really be compared with either Kubrick's or Spielberg's films, THE DAY TIME ENDED is much better than many other 2001/CLOSE ENCOUNTERS knock-offs. I give credit to director John 'Bud' Cardos, whose 1977 thriller KINGDOM OF THE SPIDERS made for an interesting precursor to ARACHNOPHOBIA, for at least trying--and on that basis, I give THE DAY TIME ENDED a 7 out of 10.
# Sentiment: Positive
#
# Text: I did a review for this director's fictional recreation about BTK. I had also seen this movie and it was terrible. Please save your money and time. This movie was terrible and this director is untalented. I do not understand how he is funding these movies. They are horrible. I have decided to make sure that I check who the writer, director, and producer are, and if this director's name pops up I will not waste my money. There is nothing worse than renting a movie on a Friday night, making the popcorn, and then realizing you have been duped by creative art on the front of the movie box. Stay away. So I guess I should make up some stuff to fill in the lines? I have always checked IMDb for reviews before, but I think I will not anymore. This is ridiculous. I have been corrected in my reviews far too many times. Not enough lines? You may cancel my account. Your site is a pain.
# Sentiment: Negative
#
# Text: {text}
# Sentiment: """
#     return prompt_output
# ```
# #### `datasets/teacher_rand_example_few_shot_predictions.parquet`
# This uses a randomized examples for the few shot (3 examples, can be changed). This is to compare it to a set few shot model. The code for this is seen below. This was how the training dataset was created.
# ```python
# def model_prompt(ex: str, labels: dict) -> str:
#     examples = teacher_train_df.sample(n=3)
#     output = f"Classify the sentiment of the following texts as either {', '.join(list(labels.values())[:-1])}, or {list(labels.values())[-1]}.\n\n"
#     if len(examples) > 0:
#         for i, row in examples.iterrows():
#             output += f'Text: {row["text"]}\nSentiment: {labels[row["label"]]}\n\n'
#     output += f'Text: {ex}\nSentiment: '
#     return output
# ```
#
#
# #### `datasets/teacher_dolphin_predictions.parquet`
#
# Was run on the Dolphin 3.0 8B Model with the following prompt.
#
# ```python
# def model_prompt(text: str, _) -> str:
#     prompt_output = f"""Classify the sentiment of the following texts as either Negative, or Positive.
#
# Text: This is such a crappy movie I have no idea how it got on the shelves, they must have paid the movie store to make them put it there, seriously! The story makes absolutely no sense unless you are on some seriously heavy drugs, you would definitely have to be on something in order to watch this total piece of garbage, so much so that you would not care what was on the TV because you're almost in a coma. The writing sounds like it was done by a 5-year-old and the acting is worse than grade school plays. The hideous special effects they were trying to do look so stupid, what did they spend a whole $5 to make the entire movie, it looks like it! Oh my, that scene with the old woman who has an 80's hairdo and the ugly girls in the rubber suits, me and my friends laughed so hard. Did someone actually think it was a good idea to make this into a movie? I find that hard to believe!
# Sentiment: Negative
#
# Text: Wow! I have seen so many bad low budget films lately, but this one is great. The very realistic portrayal of police life in a city on the East German coast is a strong contrast to other crime movies or series. I loved the main actress and the absolute rejection of any prevalent cliché about the police. This film is realistic like a documentation and entertaining like a drama at the same time. A perfect tradeoff!
# Sentiment: Positive
#
# Text: I've seen tons of science fiction from the 70s; some horrendously bad, and others thought provoking and truly frightening. Soylent Green fits into the latter category. Yes, at times it's a little campy, and yes, the furniture is good for a giggle or two, but some of the film seems awfully prescient. Here we have a film, 9 years before Blade Runner, that dares to imagine the future as somthing dark, scary, and nihilistic. Both Charlton Heston and Edward G. Robinson fare far better in this than The Ten Commandments, and Robinson's assisted-suicide scene is creepily prescient of Kevorkian and his ilk. Some of the attitudes are dated (can you imagine a filmmaker getting away with the "women as furniture" concept in our oh-so-politically-correct-90s?), but it's rare to find a film from the Me Decade that actually can make you think. This is one I'd love to see on the big screen, because even in a widescreen presentation, I don't think the overall scope of this film would receive its due. Check it out.
# Sentiment: Positive
#
# Text: {text}
# Sentiment: """
#     return prompt_output
# ```

# %%
# from hugging_face_model import HFModel

# llama_31 = HFModel()

# llama_31.load_model("dphn/Dolphin3.0-Llama3.1-8B")

# llama_31.set_labels({0: "Negative", 1: "Positive"})
# # Randome sample prompt function
# def model_prompt(text: str, _) -> str:
#     prompt_output = f"""Classify the sentiment of the following texts as either Negative, or Positive.

# Text: This is such a crappy movie I have no idea how it got on the shelves, they must have paid the movie store to make them put it there, seriously! The story makes absolutely no sense unless you are on some seriously heavy drugs, you would definitely have to be on something in order to watch this total piece of garbage, so much so that you would not care what was on the TV because you're almost in a coma. The writing sounds like it was done by a 5-year-old and the acting is worse than grade school plays. The hideous special effects they were trying to do look so stupid, what did they spend a whole $5 to make the entire movie, it looks like it! Oh my, that scene with the old woman who has an 80's hairdo and the ugly girls in the rubber suits, me and my friends laughed so hard. Did someone actually think it was a good idea to make this into a movie? I find that hard to believe!
# Sentiment: Negative

# Text: Wow! I have seen so many bad low budget films lately, but this one is great. The very realistic portrayal of police life in a city on the East German coast is a strong contrast to other crime movies or series. I loved the main actress and the absolute rejection of any prevalent cliché about the police. This film is realistic like a documentation and entertaining like a drama at the same time. A perfect tradeoff!
# Sentiment: Positive

# Text: I've seen tons of science fiction from the 70s; some horrendously bad, and others thought provoking and truly frightening. Soylent Green fits into the latter category. Yes, at times it's a little campy, and yes, the furniture is good for a giggle or two, but some of the film seems awfully prescient. Here we have a film, 9 years before Blade Runner, that dares to imagine the future as somthing dark, scary, and nihilistic. Both Charlton Heston and Edward G. Robinson fare far better in this than The Ten Commandments, and Robinson's assisted-suicide scene is creepily prescient of Kevorkian and his ilk. Some of the attitudes are dated (can you imagine a filmmaker getting away with the "women as furniture" concept in our oh-so-politically-correct-90s?), but it's rare to find a film from the Me Decade that actually can make you think. This is one I'd love to see on the big screen, because even in a widescreen presentation, I don't think the overall scope of this film would receive its due. Check it out.
# Sentiment: Positive

# Text: {text}
# Sentiment: """
#     return prompt_output
# llama_31.set_prompt(model_prompt)

# %%
# # Correct format for downloading raw files from Hugging Face datasets
# ds = pd.read_parquet(
#     "https://huggingface.co/api/datasets/peixian/equity_evaluation_corpus/parquet/first_domain/train/0.parquet"
# )

# label_prob = []
# for sentence in tqdm(ds['sentence']):
#     probs = llama_31.predict(sentence)
#     label_prob.append(probs.numpy())
# # Convert to numpy array and transpose to slice correctly
# label_prob = np.array(label_prob).T
# # Add the probabilities to the dataframe
# ds['0'], ds['1'] = label_prob
# notifier.send_notification("Finished Running through Teacher Model Predictions")
# # Save the dataframe with predictions
# ds.to_parquet("datasets/teacher_dolphin_predictions.parquet")
# notifier.send_notification("Saved Teacher Model Predictions to Parquet File")
# ds.head()

# %%
ds = import_predictions("datasets/teacher_model_predictions.parquet", rm_columns=['0'], rename_columns={"1": "prediction"})

ds['gender'] = ds['gender'].replace('', 'No Gender')
ds['race'] = ds['race'].replace('', 'No Race')
ds['emotion'] = ds['emotion'].replace('', 'No Emotion')

fig, ax = plt.subplots(figsize=(12, 6))

sns.boxplot(
    x="emotion", y="prediction",
    hue="race", palette=race_palette,
    data=ds,
    whis=(0, 100),
    ax=ax
)

sns.despine(offset=10, trim=True)

ax.legend(loc='lower right')
ax.set_title("Llama Teacher Model Predictions by Emotion and Race", fontsize=16)
ax.set_xlabel("Emotion", fontsize=14)
ax.set_ylabel("Probability of Positive Sentiment", fontsize=14)

ax.legend(loc='lower right')

fig.savefig("graphs/llama/model_predictions_by_emotion_and_race.png", dpi=300)

# notifier.send_image("Llama Teacher Model Predictions by Emotion and Race", "graphs/llama/model_predictions_by_emotion_and_race.png")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

sns.boxplot(
    x="emotion", y="prediction",
    hue="gender", palette=gender_palette,
    data=ds,
    whis=(0, 100),
    ax=ax
)

sns.despine(offset=10, trim=True)

ax.legend(loc='lower right')
ax.set_title("Llama Teacher Model Predictions by Emotion and Gender", fontsize=16)
ax.set_xlabel("Emotion", fontsize=14)
ax.set_ylabel("Probability of Positive Sentiment", fontsize=14)

fig.savefig("graphs/llama/model_predictions_by_emotion_and_gender.png", dpi=300)

# notifier.send_image("Llama Teacher Model Predictions by Emotion and Gender", "graphs/llama/model_predictions_by_emotion_and_gender.png")
plt.show()

# %% [markdown]
# ## Analyzing the EEC Datatset Results

# %% [markdown]
# Import EEC Prediction Datasets and Combine them into one DataFrame for Easy comparison

# %%
def graph_ratios_by_variable(ds: pd.DataFrame, y_column: str, variable: str, title_start: str, palette: List[str], save_path: str):
    """Graphs the ratios of distilled to baseline model predictions by a specified variable.

    Args:
        ds (pd.DataFrame): The dataframe containing the data.
        y_column (str): The column name for the y-axis values.
        variable (str): The variable column name to compare ratios for.
        title_start (str): The starting string for the plot title.
        palette (List[str]): The color palette for the plot.
        save_path (str): The file path to save the graph.
    """
    fig, ax = plt.subplots(figsize=(12, 6))

    ax.set_yscale('log')

    sns.boxplot(
        x="emotion", y=y_column,
        hue=variable, palette=palette,
        data=ds,
        whis=(0, 100),
        ax=ax
    )

    sns.despine(offset=10, trim=True)

    ax.legend()#loc='upper right')

    ax.set_title(f"{title_start} Prediction Ratios by Emotion and {variable.capitalize()}", fontsize=16)
    ax.set_ylabel("Distilled / Baseline Positive Prediction Ratio", fontsize=14)
    ax.set_xlabel("Emotion", fontsize=14)

    ax.grid(axis='y')

    fig.tight_layout()

    fig.savefig(save_path, dpi=300)

# %%
def graph_differences_by_variable(ds: pd.DataFrame, y_column: str, variable: str, palette: List[str], save_path: str, title_start: str = "", plot_type: str = 'box'):
    """Graphs the differences of distilled to baseline model predictions by a specified variable.

    Args:
        ds (pd.DataFrame): The dataframe containing the data.
        y_column (str): The column name for the y-axis values.
        variable (str): The variable column name to compare differences for.
        title_start (str): The starting string for the plot title.
        palette (List[str]): The color palette for the plot.
        save_path (str): The file path to save the graph.
    """
    fig, ax = plt.subplots(figsize=(10, 5))

    if plot_type == 'box':
        sns.boxplot(
            x="emotion", y=y_column,
            hue=variable, palette=palette,
            data=ds,
            # whis=(0, 100),
            flierprops={"marker": "_", "markersize": 2},
            ax=ax
        )
    elif plot_type == 'violin':
        sns.violinplot(
            x="emotion", y=y_column,
            hue=variable, palette=palette,
            data=ds,
            # split=True,
            inner="quart",
            # whis=(0, 100),
            # flierprops={"marker": "_", "markersize": 2},
            ax=ax
        )
    else:
        raise ValueError("Invalid plot_type. Must be 'boxplot' or 'violinplot'.")

    sns.despine(offset=10, trim=True)

    ax.set_ylabel("$\Delta$ Positive Prediction", fontsize=14)
    ax.set_xlabel("Emotion", fontsize=14)

    if title_start != "":
        ax.set_title(f"{title_start} Prediction Differences by Emotion and {variable.capitalize()}", fontsize=16)

    ax.grid(axis='y')

    fig.tight_layout()

    ax.legend()

    fig.savefig(save_path, dpi=300)

# %% [markdown]
# Import all the EEC predictions for all models

# %%
ds = import_predictions("datasets/teacher_model_predictions.parquet", rm_columns=['0'], rename_columns={"1": "Llama"})
ds = import_to_ds(ds, "datasets/eec_predictions_bow_baseline.csv", prediction_columns=["pos_prob"], rename_columns={"pos_prob": "BOW Baseline"})
ds = import_to_ds(ds, "datasets/eec_predictions_bow_distilled1.csv", prediction_columns=["pos_prob"], rename_columns={"pos_prob": "BOW Distilled"})
ds = import_to_ds(ds, "datasets/eec_predictions_cnn_baseline.csv", prediction_columns=["pos_prob"], rename_columns={"pos_prob": "CNN Baseline"})
ds = import_to_ds(ds, "datasets/eec_predictions_cnn_distilled1.csv", prediction_columns=["pos_prob"], rename_columns={"pos_prob": "CNN Distilled"})
ds = import_to_ds(ds, "datasets/distilbert_trained_EEC_predictions.parquet", prediction_columns=["label_1"], rename_columns={"label_1": "BERT Baseline", "Sentence": "sentence"})
ds = import_to_ds(ds, "datasets/distilbert_distilled_EEC_predictions.parquet", prediction_columns=["label_1"], rename_columns={"label_1": "BERT Distilled", "Sentence": "sentence"})

ds['gender'] = ds['gender'].replace({'': 'No Gender', "male": "Male", "female": "Female"})
ds['race'] = ds['race'].replace('', 'No Race')
ds['emotion'] = ds['emotion'].replace({'': 'No Emotion', "anger": "Anger", "fear": "Fear", "joy": "Joy", "sadness": "Sadness", "surprise": "Surprise"})

ds.head(5)
# Out:
#                   sentence                                template  person  \
# 0      Alonzo feels angry.  <person subject> feels <emotion word>.  Alonzo
# 1    Alonzo feels furious.  <person subject> feels <emotion word>.  Alonzo
# 2  Alonzo feels irritated.  <person subject> feels <emotion word>.  Alonzo
# 3    Alonzo feels enraged.  <person subject> feels <emotion word>.  Alonzo
# 4    Alonzo feels annoyed.  <person subject> feels <emotion word>.  Alonzo
#
#   gender              race emotion emotion word     Llama  BOW Baseline  \
# 0   Male  African-American   Anger        angry  0.247964      0.001902
# 1   Male  African-American   Anger      furious  0.236573      0.016993
# 2   Male  African-American   Anger    irritated  0.161325      0.001643
# 3   Male  African-American   Anger      enraged  0.259896      0.019729
# 4   Male  African-American   Anger      annoyed  0.191960      0.000346
#
#    BOW Distilled  CNN Baseline  CNN Distilled  BERT Baseline  BERT Distilled
# 0       0.017086      0.461344       0.508674       0.005657        0.167155
# 1       0.025428      0.506426       0.471639       0.380767        0.352053
# 2       0.000267      0.457656       0.352700       0.000187        0.041459
# 3       0.020630      0.501603       0.523213       0.021282        0.191704
# 4       0.000748      0.464335       0.502585       0.000150        0.037597

# %% [markdown]
# Creates a new dataframe which restructures the `ds` dataframe to add another column for the model and remove the individual prediction columns.
#
# Additionally calculates deviations from emotion mean so that differences in the model predictions can be better understood.

# %%
model_cols = ds.columns[~ds.columns.isin(['sentence', 'template', 'person', 'gender', 'race', 'emotion', 'emotion word'])].tolist()

ds_model_cols = ds.melt(
        id_vars=['sentence', 'template', 'person', 'gender', 'race', 'emotion', 'emotion word'],
        value_vars=model_cols,
        var_name='Model',
        value_name='prediction'
        )

ds_model_cols['model_type'] = ds_model_cols['Model'].apply(lambda x: 'Distilled' if 'Distilled' in x else 'Baseline' if 'Baseline' in x else 'Llama')

ds_model_cols['model_family'] = ds_model_cols['Model'].apply(
    lambda x: x.replace(' Baseline', '').replace(' Distilled', '')
)

# Get the llama means for each of the emotions, the llama emotion deltas was written by Claude Opus 4.5

llama_means = (ds_model_cols[ds_model_cols['model_type'] == 'Llama']
               .groupby('emotion')['prediction']
               .mean()
               .reset_index(name='llama_mean'))

# Merge the llama means back to the main dataframe
ds_model_cols = ds_model_cols.merge(llama_means, on='emotion', how='left')
# Actually calcuilates the mean
ds_model_cols['llama_emotion_mean_dev'] = ds_model_cols['prediction'] - ds_model_cols['llama_mean']

# Calculate Baseline mean for each model family and emotion, then merge back. Generated by Claude Opus 4.5 and modified by me so that for Llama it will just use the Llama mean
baseline_means = (ds_model_cols[(ds_model_cols['model_type'] == 'Baseline') | (ds_model_cols['model_type'] == 'Llama')]
                  .groupby(['model_family', 'emotion'])['prediction']
                  .mean()
                  .reset_index(name='baseline_mean'))

ds_model_cols = ds_model_cols.merge(baseline_means, on=['model_family', 'emotion'], how='left')
ds_model_cols['baseline_emotion_mean_dev'] = ds_model_cols['prediction'] - ds_model_cols['baseline_mean']

# The deviation from the mean emotion for llama model
# ds_model_cols['llama_emotion_mean_dev'] = ds_model_cols.groupby(['emotion'])['prediction'].transform(lambda x: x - x.mean())
ds_model_cols['deviation_on_emotion'] = ds_model_cols.groupby(['Model', 'emotion'])['prediction'].transform(lambda x: x - x.mean())
ds_model_cols.head(5)
# Out:
#                   sentence                                template  person  \
# 0      Alonzo feels angry.  <person subject> feels <emotion word>.  Alonzo
# 1    Alonzo feels furious.  <person subject> feels <emotion word>.  Alonzo
# 2  Alonzo feels irritated.  <person subject> feels <emotion word>.  Alonzo
# 3    Alonzo feels enraged.  <person subject> feels <emotion word>.  Alonzo
# 4    Alonzo feels annoyed.  <person subject> feels <emotion word>.  Alonzo
#
#   gender              race emotion emotion word  Model  prediction model_type  \
# 0   Male  African-American   Anger        angry  Llama    0.247964      Llama
# 1   Male  African-American   Anger      furious  Llama    0.236573      Llama
# 2   Male  African-American   Anger    irritated  Llama    0.161325      Llama
# 3   Male  African-American   Anger      enraged  Llama    0.259896      Llama
# 4   Male  African-American   Anger      annoyed  Llama    0.191960      Llama
#
#   model_family  llama_mean  llama_emotion_mean_dev  baseline_mean  \
# 0        Llama    0.237059                0.010904       0.237059
# 1        Llama    0.237059               -0.000486       0.237059
# 2        Llama    0.237059               -0.075735       0.237059
# 3        Llama    0.237059                0.022837       0.237059
# 4        Llama    0.237059               -0.045099       0.237059
#
#    baseline_emotion_mean_dev  deviation_on_emotion
# 0                   0.010904              0.010904
# 1                  -0.000486             -0.000486
# 2                  -0.075735             -0.075735
# 3                   0.022837              0.022837
# 4                  -0.045099             -0.045099

# %% [markdown]
# Overall Model Predictions

# %%
fig, ax = plt.subplots(figsize=(10, 5))

sns.boxplot(
    x="emotion", y="prediction",
    hue="Model", #palette=["m", "g", 'b'],
    data=ds_model_cols,
    # whis=(0, 100),
    flierprops={"marker": "_", "markersize": 2},
    # legend='full',
    ax=ax
)

sns.despine(offset=10, trim=True)

ax.grid(axis='y', which='both')

# ax.legend(fancybox=True, shadow=True)#loc='lower right')
ax.legend(
    title="Model",
    # ncol=8,
    title_fontsize=8,
    fontsize=7,
    # handlelength=1.5,
    # columnspacing=1,
    # loc='lower center'
)
# ax.set_title("Model Predictions by Emotion", fontsize=16)
ax.set_xlabel("Emotion", fontsize=14)
ax.set_ylabel("Positive Sentiment Probability", fontsize=14)

fig.tight_layout()

fig.savefig("graphs/model_predictions_by_emotion.png", dpi=300)

plt.show()

# %% [markdown]
# Model Predictions Deviation from Llamas Mean by each emotion.

# %%
fig, ax = plt.subplots(figsize=(10, 5))

sns.boxplot(
    x="gender", y="llama_emotion_mean_dev",
    hue="Model", #palette=["m", "g", 'b'],
    data=ds_model_cols,
    # whis=(0, 100),
    flierprops={"marker": "_", "markersize": 2},
    # legend='full',
    ax=ax
)

sns.despine(offset=10, trim=True)

ax.grid(axis='y', which='both')

ax.legend(
    title="Model",
    # ncol=2,
    title_fontsize=8,
    fontsize=7,
    handlelength=1.5,
    columnspacing=1,
    # loc='upper right'
)
#fancybox=True, shadow=True)#, prop={'size': 8})#loc='lower right')

# ax.set_title("Model Predictions by Emotion", fontsize=16)
ax.set_xlabel("Gender", fontsize=14)
ax.set_ylabel("$\Delta$Sentiment from Llama Emotion Mean", fontsize=14)

fig.tight_layout()

fig.savefig("graphs/model_predictions_mean_llama_emotion_deviation_by_gender.png", dpi=300)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 5))

sns.boxplot(
    x="race", y="llama_emotion_mean_dev",
    hue="Model", #palette=["m", "g", 'b'],
    data=ds_model_cols,
    # whis=(0, 100),
    flierprops={"marker": "_", "markersize": 2},
    # legend='full',
    ax=ax
)

sns.despine(offset=10, trim=True)

ax.grid(axis='y', which='both')

ax.legend(
    title="Model",
    # ncol=2,
    title_fontsize=8,
    fontsize=7,
    handlelength=1.5,
    columnspacing=1,
    # loc='upper right'
)
#fancybox=True, shadow=True)#, prop={'size': 8})#loc='lower right')

# ax.set_title("Model Predictions by Emotion", fontsize=16)
ax.set_xlabel("Race", fontsize=14)
ax.set_ylabel("$\Delta$Sentiment from Llama Emotion Mean", fontsize=14)

fig.tight_layout()

fig.savefig("graphs/model_predictions_mean_llama_emotion_deviation_by_race.png", dpi=300)

plt.show()

# %% [markdown]
# Bag of Words Distillation Delta from Baseline Model

# %%
# Get ratios between BOW Baseline and distilled
ds['bow_distil_ratio'] = ds['BOW Distilled'] / ds['BOW Baseline']
# Get differences between BOW Baseline and distilled
ds['bow_distil_diff'] = ds['BOW Distilled'] - ds['BOW Baseline']

print(f"Percent w/ No Difference (BOW Distilled vs Baseline): {ds['bow_distil_diff'].eq(0).mean() * 100:.2f}%")


graph_differences_by_variable(ds, "bow_distil_diff", "race", race_palette, "graphs/bow/distilled_vs_baseline_differences_by_emotion_and_race.png")#, title_start="Bag of Words Distilled vs Baseline")
graph_differences_by_variable(ds, "bow_distil_diff", "gender", gender_palette, "graphs/bow/distilled_vs_baseline_differences_by_emotion_and_gender.png")#, title_start="Bag of Words Distilled vs Baseline")


graph_differences_by_variable(ds, "bow_distil_diff", "race", race_palette, "graphs/bow/distilled_vs_baseline_differences_by_emotion_and_race_violin.png", plot_type='violin')#, title_start="Bag of Words Distilled vs Baseline")
graph_differences_by_variable(ds, "bow_distil_diff", "gender", gender_palette, "graphs/bow/distilled_vs_baseline_differences_by_emotion_and_gender_violin.png", plot_type='violin')#, title_start="Bag of Words Distilled vs Baseline")
# graph_ratios_by_variable(ds, "bow_distil_ratio", "race", "Bag of Words Distilled vs Baseline", race_palette, "graphs/bow/distilled_vs_baseline_ratios_by_emotion_and_race.png")
# graph_ratios_by_variable(ds, "bow_distil_ratio", "gender", "Bag of Words Distilled vs Baseline", gender_palette, "graphs/bow/distilled_vs_baseline_ratios_by_emotion_and_gender.png")
# Out:
# Percent w/ No Difference (BOW Distilled vs Baseline): 4.02%

# %%
print(f"Percent w/ Difference < 0.01 (BOW Distilled vs Baseline): {(ds['bow_distil_diff'].abs() < 0.01).sum() / len(ds) * 100:.2f}%")
print(f"Percent w/ Difference < 0.001 (BOW Distilled vs Baseline): {(ds['bow_distil_diff'].abs() < 0.001).sum() / len(ds) * 100:.2f}%")
print(f"Percent w/ No Difference (BOW Distilled vs Baseline): {(ds['bow_distil_diff'].abs() == 0).sum() / len(ds) * 100:.2f}%")

print(f"Average Male BOW difference: {ds[ds['gender'] == 'Male']['bow_distil_diff'].mean():.4f}")
print(f"Average Female BOW difference: {ds[ds['gender'] == 'Female']['bow_distil_diff'].mean():.4f}\n")
for emotion in ds['emotion'].unique():
    print(f"Emotion Average: {ds[(ds['emotion'] == emotion)]['bow_distil_diff'].mean():.4f}")
    print(f"Average Male {emotion} BOW difference: {ds[(ds['gender'] == 'Male') & (ds['emotion'] == emotion)]['bow_distil_diff'].mean():.4f}")
    print(f"Average Female {emotion} BOW difference: {ds[(ds['gender'] == 'Female') & (ds['emotion'] == emotion)]['bow_distil_diff'].mean():.4f}\n")
# Out:
# Percent w/ Difference < 0.01 (BOW Distilled vs Baseline): 52.16%
# Percent w/ Difference < 0.001 (BOW Distilled vs Baseline): 34.40%
# Percent w/ No Difference (BOW Distilled vs Baseline): 4.02%
# Average Male BOW difference: -0.0417
# Average Female BOW difference: -0.0219
#
# Emotion Average: -0.0412
# Average Male Anger BOW difference: -0.0530
# Average Female Anger BOW difference: -0.0295
#
# Emotion Average: -0.0899
# Average Male Sadness BOW difference: -0.1016
# Average Female Sadness BOW difference: -0.0783
#
# Emotion Average: -0.0232
# Average Male Fear BOW difference: -0.0323
# Average Female Fear BOW difference: -0.0140
#
# Emotion Average: 0.0233
# Average Male Joy BOW difference: 0.0165
# Average Female Joy BOW difference: 0.0300
#
# Emotion Average: 0.0038
# Average Male No Emotion BOW difference: -0.0094
# Average Female No Emotion BOW difference: 0.0169

# %%
for race in ds['race'].unique():
    print(f"Average {race} BOW difference: {ds[(ds['race'] == race)]['bow_distil_diff'].mean():.4f}")

print()
for emotion in ds['emotion'].unique():
    print(f"Emotion Average: {ds[(ds['emotion'] == emotion)]['bow_distil_diff'].mean():.4f}")
    for race in ds['race'].unique():
        print(f"Average {race} {emotion} BOW difference: {ds[(ds['race'] == race) & (ds['emotion'] == emotion)]['bow_distil_diff'].mean():.4f}")
    print()
# Out:
# Average African-American BOW difference: -0.0203
# Average European BOW difference: -0.0401
# Average No Race BOW difference: -0.0349
#
# Emotion Average: -0.0412
# Average African-American Anger BOW difference: -0.0224
# Average European Anger BOW difference: -0.0525
# Average No Race Anger BOW difference: -0.0488
#
# Emotion Average: -0.0899
# Average African-American Sadness BOW difference: -0.0870
# Average European Sadness BOW difference: -0.0969
# Average No Race Sadness BOW difference: -0.0859
#
# Emotion Average: -0.0232
# Average African-American Fear BOW difference: -0.0151
# Average European Fear BOW difference: -0.0313
# Average No Race Fear BOW difference: -0.0231
#
# Emotion Average: 0.0233
# Average African-American Joy BOW difference: 0.0413
# Average European Joy BOW difference: 0.0146
# Average No Race Joy BOW difference: 0.0138
#
# Emotion Average: 0.0038
# Average African-American No Emotion BOW difference: -0.0039
# Average European No Emotion BOW difference: 0.0108
# Average No Race No Emotion BOW difference: 0.0045

# %%
for emotion in ds['emotion'].unique():
    print(f"{emotion} Average: {ds[(ds['emotion'] == emotion)]['bow_distil_diff'].mean():.4f}")
    for race in ds['race'].unique():
        for gender in ds['gender'].unique():
            data_of_interest = ds[(ds['race'] == race) & (ds['emotion'] == emotion) & (ds['gender'] == gender)]
            print(f"Average {race} {emotion} {gender} BOW difference: {data_of_interest['bow_distil_diff'].mean():.4f}; Distilled Mean: {data_of_interest['BOW Distilled'].mean():.4f}; Baseline Mean: {data_of_interest['BOW Baseline'].mean():.4f}")
    print()
# Out:
# Anger Average: -0.0412
# Average African-American Anger Male BOW difference: -0.0246; Distilled Mean: 0.5468; Baseline Mean: 0.5714
# Average African-American Anger Female BOW difference: -0.0202; Distilled Mean: 0.5517; Baseline Mean: 0.5719
# Average European Anger Male BOW difference: -0.0843; Distilled Mean: 0.5123; Baseline Mean: 0.5966
# Average European Anger Female BOW difference: -0.0207; Distilled Mean: 0.5250; Baseline Mean: 0.5457
# Average No Race Anger Male BOW difference: -0.0501; Distilled Mean: 0.6623; Baseline Mean: 0.7124
# Average No Race Anger Female BOW difference: -0.0476; Distilled Mean: 0.6020; Baseline Mean: 0.6496
#
# Sadness Average: -0.0899
# Average African-American Sadness Male BOW difference: -0.0913; Distilled Mean: 0.6026; Baseline Mean: 0.6939
# Average African-American Sadness Female BOW difference: -0.0826; Distilled Mean: 0.6119; Baseline Mean: 0.6946
# Average European Sadness Male BOW difference: -0.1220; Distilled Mean: 0.5808; Baseline Mean: 0.7028
# Average European Sadness Female BOW difference: -0.0718; Distilled Mean: 0.5951; Baseline Mean: 0.6670
# Average No Race Sadness Male BOW difference: -0.0914; Distilled Mean: 0.7157; Baseline Mean: 0.8072
# Average No Race Sadness Female BOW difference: -0.0805; Distilled Mean: 0.6647; Baseline Mean: 0.7452
#
# Fear Average: -0.0232
# Average African-American Fear Male BOW difference: -0.0172; Distilled Mean: 0.6357; Baseline Mean: 0.6529
# Average African-American Fear Female BOW difference: -0.0131; Distilled Mean: 0.6412; Baseline Mean: 0.6543
# Average European Fear Male BOW difference: -0.0539; Distilled Mean: 0.6048; Baseline Mean: 0.6587
# Average European Fear Female BOW difference: -0.0086; Distilled Mean: 0.6146; Baseline Mean: 0.6232
# Average No Race Fear Male BOW difference: -0.0259; Distilled Mean: 0.7382; Baseline Mean: 0.7640
# Average No Race Fear Female BOW difference: -0.0204; Distilled Mean: 0.6856; Baseline Mean: 0.7060
#
# Joy Average: 0.0233
# Average African-American Joy Male BOW difference: 0.0413; Distilled Mean: 0.8233; Baseline Mean: 0.7820
# Average African-American Joy Female BOW difference: 0.0413; Distilled Mean: 0.8234; Baseline Mean: 0.7821
# Average European Joy Male BOW difference: -0.0045; Distilled Mean: 0.8034; Baseline Mean: 0.8079
# Average European Joy Female BOW difference: 0.0337; Distilled Mean: 0.8092; Baseline Mean: 0.7755
# Average No Race Joy Male BOW difference: 0.0128; Distilled Mean: 0.8863; Baseline Mean: 0.8735
# Average No Race Joy Female BOW difference: 0.0149; Distilled Mean: 0.8495; Baseline Mean: 0.8346
#
# No Emotion Average: 0.0038
# Average African-American No Emotion Male BOW difference: -0.0039; Distilled Mean: 0.9400; Baseline Mean: 0.9439
# Average African-American No Emotion Female BOW difference: -0.0039; Distilled Mean: 0.9400; Baseline Mean: 0.9439
# Average European No Emotion Male BOW difference: -0.0066; Distilled Mean: 0.8480; Baseline Mean: 0.8546
# Average European No Emotion Female BOW difference: 0.0281; Distilled Mean: 0.8889; Baseline Mean: 0.8608
# Average No Race No Emotion Male BOW difference: -0.0176; Distilled Mean: 0.9640; Baseline Mean: 0.9816
# Average No Race No Emotion Female BOW difference: 0.0266; Distilled Mean: 0.8997; Baseline Mean: 0.8732

# %% [markdown]
# CNN Distillation Delta from Baseline Model

# %%
ds['cnn_distil_diff'] = ds['CNN Distilled'] - ds['CNN Baseline']
ds['cnn_distil_ratio'] = ds['CNN Distilled'] / ds['CNN Baseline']

graph_differences_by_variable(ds, "cnn_distil_diff", "race", race_palette, "graphs/cnn/distilled_vs_baseline_differences_by_emotion_and_race.png")
graph_differences_by_variable(ds, "cnn_distil_diff", "gender", gender_palette, "graphs/cnn/distilled_vs_baseline_differences_by_emotion_and_gender.png")

graph_differences_by_variable(ds, "cnn_distil_diff", "race", race_palette, "graphs/cnn/distilled_vs_baseline_differences_by_emotion_and_race_violin.png", plot_type='violin')
graph_differences_by_variable(ds, "cnn_distil_diff", "gender", gender_palette, "graphs/cnn/distilled_vs_baseline_differences_by_emotion_and_gender_violin.png", plot_type='violin')

# graph_ratios_by_variable(ds, "cnn_distil_ratio", "race", "CNN Distilled vs Baseline", race_palette, "graphs/cnn/distilled_vs_baseline_ratios_by_emotion_and_race.png")
# graph_ratios_by_variable(ds, "cnn_distil_ratio", "gender", "CNN Distilled vs Baseline", gender_palette, "graphs/cnn/distilled_vs_baseline_ratios_by_emotion_and_gender.png")

# %%
print(f"Percent w/ Difference < 0.01 (CNN Distilled vs Baseline): {(ds['cnn_distil_diff'].abs() < 0.01).sum() / len(ds) * 100:.2f}%")
print(f"Percent w/ Difference < 0.001 (CNN Distilled vs Baseline): {(ds['cnn_distil_diff'].abs() < 0.001).sum() / len(ds) * 100:.2f}%")
print(f"Percent w/ No Difference (CNN Distilled vs Baseline): {(ds['cnn_distil_diff'].abs() == 0).sum() / len(ds) * 100:.2f}%")

print(f"Average Male CNN difference: {ds[ds['gender'] == 'Male']['cnn_distil_diff'].mean():.4f}")
print(f"Average Female CNN difference: {ds[ds['gender'] == 'Female']['cnn_distil_diff'].mean():.4f}\n")
for emotion in ds['emotion'].unique():
    print(f"Emotion Average: {ds[(ds['emotion'] == emotion)]['cnn_distil_diff'].mean():.4f}")
    print(f"Average Male {emotion} CNN difference: {ds[(ds['gender'] == 'Male') & (ds['emotion'] == emotion)]['cnn_distil_diff'].mean():.4f}")
    print(f"Average Female {emotion} CNN difference: {ds[(ds['gender'] == 'Female') & (ds['emotion'] == emotion)]['cnn_distil_diff'].mean():.4f}\n")
# Out:
# Percent w/ Difference < 0.01 (CNN Distilled vs Baseline): 7.93%
# Percent w/ Difference < 0.001 (CNN Distilled vs Baseline): 0.84%
# Percent w/ No Difference (CNN Distilled vs Baseline): 0.00%
# Average Male CNN difference: -0.0056
# Average Female CNN difference: -0.0207
#
# Emotion Average: 0.0246
# Average Male Anger CNN difference: 0.0349
# Average Female Anger CNN difference: 0.0143
#
# Emotion Average: -0.0529
# Average Male Sadness CNN difference: -0.0462
# Average Female Sadness CNN difference: -0.0597
#
# Emotion Average: -0.0218
# Average Male Fear CNN difference: -0.0138
# Average Female Fear CNN difference: -0.0298
#
# Emotion Average: -0.0055
# Average Male Joy CNN difference: -0.0001
# Average Female Joy CNN difference: -0.0108
#
# Emotion Average: 0.0128
# Average Male No Emotion CNN difference: 0.0193
# Average Female No Emotion CNN difference: 0.0063

# %%
for race in ds['race'].unique():
    print(f"Average {race} CNN difference: {ds[(ds['race'] == race)]['cnn_distil_diff'].mean():.4f}")

print()
for emotion in ds['emotion'].unique():
    print(f"{emotion} Average: {ds[(ds['emotion'] == emotion)]['cnn_distil_diff'].mean():.4f}")
    for race in ds['race'].unique():
        print(f"Average {race} {emotion} CNN difference: {ds[(ds['race'] == race) & (ds['emotion'] == emotion)]['cnn_distil_diff'].mean():.4f}")
    print()
# Out:
# Average African-American CNN difference: -0.0029
# Average European CNN difference: 0.0164
# Average No Race CNN difference: -0.0530
#
# Anger Average: 0.0246
# Average African-American Anger CNN difference: 0.0260
# Average European Anger CNN difference: 0.0602
# Average No Race Anger CNN difference: -0.0124
#
# Sadness Average: -0.0529
# Average African-American Sadness CNN difference: -0.0375
# Average European Sadness CNN difference: -0.0242
# Average No Race Sadness CNN difference: -0.0970
#
# Fear Average: -0.0218
# Average African-American Fear CNN difference: -0.0100
# Average European Fear CNN difference: 0.0042
# Average No Race Fear CNN difference: -0.0596
#
# Joy Average: -0.0055
# Average African-American Joy CNN difference: 0.0080
# Average European Joy CNN difference: 0.0232
# Average No Race Joy CNN difference: -0.0476
#
# No Emotion Average: 0.0128
# Average African-American No Emotion CNN difference: 0.0160
# Average European No Emotion CNN difference: 0.0364
# Average No Race No Emotion CNN difference: -0.0141

# %%
for emotion in ds['emotion'].unique():
    print(f"{emotion} Average: {ds[(ds['emotion'] == emotion)]['cnn_distil_diff'].mean():.4f}")
    for race in ds['race'].unique():
        for gender in ds['gender'].unique():
            data_of_interest = ds[(ds['race'] == race) & (ds['emotion'] == emotion) & (ds['gender'] == gender)]
            print(f"Average {race} {emotion} {gender} CNN difference: {data_of_interest['cnn_distil_diff'].mean():.4f}; Distilled Mean: {data_of_interest['CNN Distilled'].mean():.4f}; Baseline Mean: {data_of_interest['CNN Baseline'].mean():.4f}")
    print()
# Out:
# Anger Average: 0.0246
# Average African-American Anger Male CNN difference: 0.0276; Distilled Mean: 0.4859; Baseline Mean: 0.4584
# Average African-American Anger Female CNN difference: 0.0244; Distilled Mean: 0.4850; Baseline Mean: 0.4606
# Average European Anger Male CNN difference: 0.0858; Distilled Mean: 0.5423; Baseline Mean: 0.4565
# Average European Anger Female CNN difference: 0.0347; Distilled Mean: 0.4689; Baseline Mean: 0.4343
# Average No Race Anger Male CNN difference: -0.0086; Distilled Mean: 0.5087; Baseline Mean: 0.5173
# Average No Race Anger Female CNN difference: -0.0162; Distilled Mean: 0.5045; Baseline Mean: 0.5207
#
# Sadness Average: -0.0529
# Average African-American Sadness Male CNN difference: -0.0384; Distilled Mean: 0.4952; Baseline Mean: 0.5336
# Average African-American Sadness Female CNN difference: -0.0367; Distilled Mean: 0.4967; Baseline Mean: 0.5333
# Average European Sadness Male CNN difference: -0.0087; Distilled Mean: 0.5474; Baseline Mean: 0.5560
# Average European Sadness Female CNN difference: -0.0398; Distilled Mean: 0.4776; Baseline Mean: 0.5174
# Average No Race Sadness Male CNN difference: -0.0915; Distilled Mean: 0.5124; Baseline Mean: 0.6039
# Average No Race Sadness Female CNN difference: -0.1025; Distilled Mean: 0.5098; Baseline Mean: 0.6123
#
# Fear Average: -0.0218
# Average African-American Fear Male CNN difference: -0.0090; Distilled Mean: 0.5054; Baseline Mean: 0.5144
# Average African-American Fear Female CNN difference: -0.0111; Distilled Mean: 0.5063; Baseline Mean: 0.5174
# Average European Fear Male CNN difference: 0.0195; Distilled Mean: 0.5652; Baseline Mean: 0.5457
# Average European Fear Female CNN difference: -0.0111; Distilled Mean: 0.5015; Baseline Mean: 0.5126
# Average No Race Fear Male CNN difference: -0.0520; Distilled Mean: 0.5430; Baseline Mean: 0.5949
# Average No Race Fear Female CNN difference: -0.0672; Distilled Mean: 0.5427; Baseline Mean: 0.6099
#
# Joy Average: -0.0055
# Average African-American Joy Male CNN difference: 0.0070; Distilled Mean: 0.6215; Baseline Mean: 0.6145
# Average African-American Joy Female CNN difference: 0.0090; Distilled Mean: 0.6230; Baseline Mean: 0.6140
# Average European Joy Male CNN difference: 0.0371; Distilled Mean: 0.6988; Baseline Mean: 0.6617
# Average European Joy Female CNN difference: 0.0093; Distilled Mean: 0.6291; Baseline Mean: 0.6197
# Average No Race Joy Male CNN difference: -0.0443; Distilled Mean: 0.6588; Baseline Mean: 0.7031
# Average No Race Joy Female CNN difference: -0.0508; Distilled Mean: 0.6571; Baseline Mean: 0.7079
#
# No Emotion Average: 0.0128
# Average African-American No Emotion Male CNN difference: 0.0160; Distilled Mean: 0.5370; Baseline Mean: 0.5210
# Average African-American No Emotion Female CNN difference: 0.0160; Distilled Mean: 0.5370; Baseline Mean: 0.5210
# Average European No Emotion Male CNN difference: 0.0500; Distilled Mean: 0.5765; Baseline Mean: 0.5265
# Average European No Emotion Female CNN difference: 0.0229; Distilled Mean: 0.5326; Baseline Mean: 0.5098
# Average No Race No Emotion Male CNN difference: -0.0082; Distilled Mean: 0.5483; Baseline Mean: 0.5566
# Average No Race No Emotion Female CNN difference: -0.0200; Distilled Mean: 0.5445; Baseline Mean: 0.5646

# %%
for race in ds['race'].unique():
    print(f"Average {race} CNN difference: {ds[(ds['race'] == race)]['cnn_distil_diff'].mean():.4f}")

print()
for emotion in ds['emotion'].unique():
    print(f"Emotion Average: {ds[(ds['emotion'] == emotion)]['cnn_distil_diff'].mean():.4f}")
    for race in ds['race'].unique():
        print(f"Average {race} {emotion} CNN difference: {ds[(ds['race'] == race) & (ds['emotion'] == emotion)]['cnn_distil_diff'].mean():.4f}")
    print()
# Out:
# Average African-American CNN difference: -0.0029
# Average European CNN difference: 0.0164
# Average No Race CNN difference: -0.0530
#
# Emotion Average: 0.0246
# Average African-American Anger CNN difference: 0.0260
# Average European Anger CNN difference: 0.0602
# Average No Race Anger CNN difference: -0.0124
#
# Emotion Average: -0.0529
# Average African-American Sadness CNN difference: -0.0375
# Average European Sadness CNN difference: -0.0242
# Average No Race Sadness CNN difference: -0.0970
#
# Emotion Average: -0.0218
# Average African-American Fear CNN difference: -0.0100
# Average European Fear CNN difference: 0.0042
# Average No Race Fear CNN difference: -0.0596
#
# Emotion Average: -0.0055
# Average African-American Joy CNN difference: 0.0080
# Average European Joy CNN difference: 0.0232
# Average No Race Joy CNN difference: -0.0476
#
# Emotion Average: 0.0128
# Average African-American No Emotion CNN difference: 0.0160
# Average European No Emotion CNN difference: 0.0364
# Average No Race No Emotion CNN difference: -0.0141

# %% [markdown]
# DistilBERT Distillation Delta from Baseline Model

# %%
# Get differences between bert and bow distilled
ds['bert_diff'] = (ds['BERT Distilled'] - ds['BERT Baseline'])
ds['bert_ratio'] = ds['BERT Distilled'] / ds['BERT Baseline']

graph_differences_by_variable(ds, "bert_diff", "race", race_palette, "graphs/distilbert/baseline_vs_distilled_differences_by_emotion_and_race.png")
graph_differences_by_variable(ds, "bert_diff", "gender", gender_palette, "graphs/distilbert/baseline_vs_distilled_differences_by_emotion_and_gender.png")
graph_differences_by_variable(ds, "bert_diff", "race", race_palette, "graphs/distilbert/baseline_vs_distilled_differences_by_emotion_and_race_violin.png", plot_type='violin')
graph_differences_by_variable(ds, "bert_diff", "gender", gender_palette, "graphs/distilbert/baseline_vs_distilled_differences_by_emotion_and_gender_violin.png", plot_type='violin')

# graph_ratios_by_variable(ds, "bert_ratio", "race", "DistilBert Baseline vs Distilled", race_palette, "graphs/distilbert/baseline_vs_distilled_ratios_by_emotion_and_race.png")
# graph_ratios_by_variable(ds, "bert_ratio", "gender", "DistilBert Baseline vs Distilled", gender_palette, "graphs/distilbert/baseline_vs_distilled_ratios_by_emotion_and_gender.png")

# %%
print(f"Percent w/ Difference < 0.01 (BERT Distilled vs Baseline): {(ds['bert_diff'].abs() < 0.01).sum() / len(ds) * 100:.2f}%")
print(f"Percent w/ Difference < 0.001 (BERT Distilled vs Baseline): {(ds['bert_diff'].abs() < 0.001).sum() / len(ds) * 100:.2f}%")
print(f"Percent w/ No Difference (BERT Distilled vs Baseline): {(ds['bert_diff'].abs() == 0).sum() / len(ds) * 100:.2f}%")

print(f"Average Male BERT difference: {ds[ds['gender'] == 'Male']['bert_diff'].mean():.4f}")
print(f"Average Female BERT difference: {ds[ds['gender'] == 'Female']['bert_diff'].mean():.4f}\n")
for emotion in ds['emotion'].unique():
    print(f"{emotion} Average: {ds[(ds['emotion'] == emotion)]['bert_diff'].mean():.4f}")
    print(f"Average Male {emotion} BERT difference: {ds[(ds['gender'] == 'Male') & (ds['emotion'] == emotion)]['bert_diff'].mean():.4f}")
    print(f"Average Female {emotion} BERT difference: {ds[(ds['gender'] == 'Female') & (ds['emotion'] == emotion)]['bert_diff'].mean():.4f}\n")
# Out:
# Percent w/ Difference < 0.01 (BERT Distilled vs Baseline): 25.35%
# Percent w/ Difference < 0.001 (BERT Distilled vs Baseline): 14.55%
# Percent w/ No Difference (BERT Distilled vs Baseline): 0.00%
# Average Male BERT difference: -0.0922
# Average Female BERT difference: -0.0951
#
# Anger Average: 0.0165
# Average Male Anger BERT difference: 0.0230
# Average Female Anger BERT difference: 0.0099
#
# Sadness Average: -0.1083
# Average Male Sadness BERT difference: -0.1051
# Average Female Sadness BERT difference: -0.1115
#
# Fear Average: -0.2541
# Average Male Fear BERT difference: -0.2593
# Average Female Fear BERT difference: -0.2490
#
# Joy Average: -0.0610
# Average Male Joy BERT difference: -0.0558
# Average Female Joy BERT difference: -0.0662
#
# No Emotion Average: 0.1899
# Average Male No Emotion BERT difference: 0.1553
# Average Female No Emotion BERT difference: 0.2245

# %%
for race in ds['race'].unique():
    print(f"Average {race} BERT difference: {ds[(ds['race'] == race)]['bert_diff'].mean():.4f}")

print()
for emotion in ds['emotion'].unique():
    print(f"Emotion Average: {ds[(ds['emotion'] == emotion)]['bert_diff'].mean():.4f}")
    for race in ds['race'].unique():
        print(f"Average {race} {emotion} BERT difference: {ds[(ds['race'] == race) & (ds['emotion'] == emotion)]['bert_diff'].mean():.4f}")
    print()
# Out:
# Average African-American BERT difference: -0.0877
# Average European BERT difference: -0.0815
# Average No Race BERT difference: -0.1118
#
# Emotion Average: 0.0165
# Average African-American Anger BERT difference: 0.0330
# Average European Anger BERT difference: 0.0169
# Average No Race Anger BERT difference: -0.0006
#
# Emotion Average: -0.1083
# Average African-American Sadness BERT difference: -0.1136
# Average European Sadness BERT difference: -0.0839
# Average No Race Sadness BERT difference: -0.1274
#
# Emotion Average: -0.2541
# Average African-American Fear BERT difference: -0.2461
# Average European Fear BERT difference: -0.2337
# Average No Race Fear BERT difference: -0.2826
#
# Emotion Average: -0.0610
# Average African-American Joy BERT difference: -0.0536
# Average European Joy BERT difference: -0.0554
# Average No Race Joy BERT difference: -0.0740
#
# Emotion Average: 0.1899
# Average African-American No Emotion BERT difference: 0.1714
# Average European No Emotion BERT difference: 0.1819
# Average No Race No Emotion BERT difference: 0.2164

# %%
for emotion in ds['emotion'].unique():
    print(f"{emotion} Average: {ds[(ds['emotion'] == emotion)]['bert_diff'].mean():.4f}; Distilled Mean: {ds[ds['emotion'] == emotion]['BERT Distilled'].mean():.4f}; Baseline Mean: {ds[ds['emotion'] == emotion]['BERT Baseline'].mean():.4f}")
    for race in ds['race'].unique():
        for gender in ds['gender'].unique():
            data_of_interest = ds[(ds['race'] == race) & (ds['emotion'] == emotion) & (ds['gender'] == gender)]
            print(f"Average {race} {emotion} {gender} BERT difference: {data_of_interest['bert_diff'].mean():.4f}; Distilled Mean: {data_of_interest['BERT Distilled'].mean():.4f}; Baseline Mean: {data_of_interest['BERT Baseline'].mean():.4f}")
    print()
# Out:
# Anger Average: 0.0165; Distilled Mean: 0.2893; Baseline Mean: 0.2728
# Average African-American Anger Male BERT difference: 0.0563; Distilled Mean: 0.3073; Baseline Mean: 0.2509
# Average African-American Anger Female BERT difference: 0.0097; Distilled Mean: 0.3254; Baseline Mean: 0.3157
# Average European Anger Male BERT difference: 0.0146; Distilled Mean: 0.3092; Baseline Mean: 0.2945
# Average European Anger Female BERT difference: 0.0192; Distilled Mean: 0.2776; Baseline Mean: 0.2584
# Average No Race Anger Male BERT difference: -0.0020; Distilled Mean: 0.2721; Baseline Mean: 0.2741
# Average No Race Anger Female BERT difference: 0.0009; Distilled Mean: 0.2441; Baseline Mean: 0.2432
#
# Sadness Average: -0.1083; Distilled Mean: 0.3308; Baseline Mean: 0.4391
# Average African-American Sadness Male BERT difference: -0.0933; Distilled Mean: 0.3316; Baseline Mean: 0.4249
# Average African-American Sadness Female BERT difference: -0.1339; Distilled Mean: 0.3389; Baseline Mean: 0.4727
# Average European Sadness Male BERT difference: -0.0918; Distilled Mean: 0.3696; Baseline Mean: 0.4614
# Average European Sadness Female BERT difference: -0.0760; Distilled Mean: 0.3387; Baseline Mean: 0.4147
# Average No Race Sadness Male BERT difference: -0.1303; Distilled Mean: 0.3183; Baseline Mean: 0.4486
# Average No Race Sadness Female BERT difference: -0.1246; Distilled Mean: 0.2878; Baseline Mean: 0.4124
#
# Fear Average: -0.2541; Distilled Mean: 0.3765; Baseline Mean: 0.6307
# Average African-American Fear Male BERT difference: -0.2398; Distilled Mean: 0.3876; Baseline Mean: 0.6274
# Average African-American Fear Female BERT difference: -0.2523; Distilled Mean: 0.4155; Baseline Mean: 0.6678
# Average European Fear Male BERT difference: -0.2565; Distilled Mean: 0.4230; Baseline Mean: 0.6795
# Average European Fear Female BERT difference: -0.2110; Distilled Mean: 0.3728; Baseline Mean: 0.5837
# Average No Race Fear Male BERT difference: -0.2815; Distilled Mean: 0.3522; Baseline Mean: 0.6337
# Average No Race Fear Female BERT difference: -0.2836; Distilled Mean: 0.3081; Baseline Mean: 0.5918
#
# Joy Average: -0.0610; Distilled Mean: 0.9213; Baseline Mean: 0.9823
# Average African-American Joy Male BERT difference: -0.0568; Distilled Mean: 0.9136; Baseline Mean: 0.9704
# Average African-American Joy Female BERT difference: -0.0503; Distilled Mean: 0.9234; Baseline Mean: 0.9737
# Average European Joy Male BERT difference: -0.0497; Distilled Mean: 0.9354; Baseline Mean: 0.9851
# Average European Joy Female BERT difference: -0.0612; Distilled Mean: 0.9191; Baseline Mean: 0.9802
# Average No Race Joy Male BERT difference: -0.0609; Distilled Mean: 0.9308; Baseline Mean: 0.9917
# Average No Race Joy Female BERT difference: -0.0872; Distilled Mean: 0.9056; Baseline Mean: 0.9928
#
# No Emotion Average: 0.1899; Distilled Mean: 0.9427; Baseline Mean: 0.7528
# Average African-American No Emotion Male BERT difference: 0.1575; Distilled Mean: 0.9426; Baseline Mean: 0.7852
# Average African-American No Emotion Female BERT difference: 0.1854; Distilled Mean: 0.9570; Baseline Mean: 0.7716
# Average European No Emotion Male BERT difference: 0.1237; Distilled Mean: 0.9587; Baseline Mean: 0.8349
# Average European No Emotion Female BERT difference: 0.2401; Distilled Mean: 0.9434; Baseline Mean: 0.7033
# Average No Race No Emotion Male BERT difference: 0.1847; Distilled Mean: 0.9349; Baseline Mean: 0.7503
# Average No Race No Emotion Female BERT difference: 0.2481; Distilled Mean: 0.9194; Baseline Mean: 0.6712
